# %%
import numpy as np

import pandas as pd
# Available in the github repo : examples/data/BTC_USD-Hourly.csv
url = "https://raw.githubusercontent.com/ClementPerroud/Gym-Trading-Env/main/examples/data/BTC_USD-Hourly.csv"
df = pd.read_csv(url, parse_dates=["date"], index_col= "date")
df.sort_index(inplace= True)
df.dropna(inplace= True)
df.drop_duplicates(inplace=True)

# %%
# df is a DataFrame with columns : "open", "high", "low", "close", "Volume USD"

# Create the feature : ( close[t] - close[t-1] )/ close[t-1]
df["feature_close"] = df["close"].pct_change()

# Create the feature : open[t] / close[t]
df["feature_open"] = df["open"]/df["close"]

# Create the feature : high[t] / close[t]
df["feature_high"] = df["high"]/df["close"]

# Create the feature : low[t] / close[t]
df["feature_low"] = df["low"]/df["close"]

 # Create the feature : volume[t] / max(*volume[t-7*24:t+1])
df["feature_volume"] = df["Volume USD"] / df["Volume USD"].rolling(7*24).max()

df.dropna(inplace= True) # Clean again !
# Eatch step, the environment will return 5 inputs  : "feature_close", "feature_open", "feature_high", "feature_low", "feature_volume"

# %%
import gymnasium as gym
import environments

#from environments import TradingEnv

# %%
import gym_trading_env

# %%
#import gymnasium as gym
#import gym_trading_env
#env = gym.make('MultiDatasetTradingEnv',
#    dataset_dir = 'preprocessed_data/*.pkl',
#    positions=[-1, 0, 1],  # -1 (=SHORT), 0(=OUT), +1 (=LONG)
#)

# %%
# Run 10 episodes
#for _ in range(10):
  # At every episode, the env will pick a new dataset.
#  done, truncated = False, False
#  observation, info = env.reset()
#  while not done and not truncated:
#      position_index = env.action_space.sample() # Pick random position index
#      observation, reward, done, truncated, info = env.step(position_index)

# %%
from environments import TradingEnv

# Create the environment directly
env = TradingEnv(
    name="BTCUSD",
    df=df,  # Your dataset with your custom features
    positions=[-0.8, 0.0, 0.8],  # -1 (=SHORT), 0(=OUT), +1 (=LONG)
    trading_fees=0.01/100,  # 0.01% per stock buy/sell (Binance fees)
    borrow_interest_rate=0.0003/100,  # 0.0003% per timestep (one timestep = 1h here)
)

# %%
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import VecEnv

# %%
policy = "MlpPolicy"

# %%
model = PPO(policy, env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Experiment with different hyperparameters based on your problem and environment
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=0.001,  # Adjust as needed
    batch_size=32,  # Adjust based on memory and learning speed
    gamma=0.99,  # Discount factor
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1117 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012114517 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -26.1       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0417     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 0.00257     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0076290956 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -1.23        |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0177      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00372     |
# |    value_loss           | 0.000109     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0094708605 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0316      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0173       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00364     |
# |    value_loss           | 0.000389     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011657371 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.581      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.000219    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 6            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0070851697 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0286      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0155      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 0.000396     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 541        |
# |    iterations           | 7          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01095647 |
# |    clip_fraction        | 0.0719     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.0837    |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0224     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00405   |
# |    value_loss           | 0.00021    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 8           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007632192 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.184      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0125      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 0.000213    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 9            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0061822534 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0168       |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.000784     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 0.0007       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 528        |
# |    iterations           | 10         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00829983 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | -0.199     |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0229    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0042    |
# |    value_loss           | 0.00028    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 11          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008540692 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.124      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00984     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0008     |
# |    value_loss           | 0.000143    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 545          |
# |    iterations           | 12           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0061048847 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.108       |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0198      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 0.000187     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 13          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004885153 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0278     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0306     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 0.00068     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 14           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0036701544 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.0143      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0101       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.000502     |
# |    value_loss           | 0.000521     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 15          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006721868 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.0106     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0251      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 0.000356    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 571          |
# |    iterations           | 16           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0074189096 |
# |    clip_fraction        | 0.0705       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.0787      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.017       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 0.000259     |
# ------------------------------------------
# Market Return : 423.10%   |   Portfolio Return : -94.47%   |
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 17          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007698025 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.0146     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0191      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 0.000279    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.31e+04   |
# |    ep_rew_mean          | -2.89      |
# | time/                   |            |
# |    fps                  | 580        |
# |    iterations           | 18         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00910975 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | -0.0752    |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.00167    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00571   |
# |    value_loss           | 0.000216   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.31e+04  |
# |    ep_rew_mean          | -2.89     |
# | time/                   |           |
# |    fps                  | 584       |
# |    iterations           | 19        |
# |    time_elapsed         | 66        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0071331 |
# |    clip_fraction        | 0.0519    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.02     |
# |    explained_variance   | -0.224    |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.0101    |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -0.00102  |
# |    value_loss           | 0.000113  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 20          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011850558 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00218    |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.025      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 0.000493    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 21          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009449257 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0595     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00254     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00339    |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 22          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006544547 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.0226     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0168     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0023     |
# |    value_loss           | 0.000364    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 23          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004374957 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.00387     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0103      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000204    |
# |    value_loss           | 0.0003      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.31e+04   |
# |    ep_rew_mean          | -2.89      |
# | time/                   |            |
# |    fps                  | 590        |
# |    iterations           | 24         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00900958 |
# |    clip_fraction        | 0.0941     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | -0.0408    |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.000462   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00612   |
# |    value_loss           | 0.00015    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 25          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007493149 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00422     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0262     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 0.000509    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 26          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008057949 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -0.0189     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0269     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 0.000326    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.89        |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 27           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0068019675 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | -0.249       |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0169       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 8.24e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 28          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008444666 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | -0.00376    |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00463    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 0.000121    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.89        |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 29           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0066787973 |
# |    clip_fraction        | 0.0773       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | -0.0268      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0273       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 0.000502     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.89        |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 30           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0051201493 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.931       |
# |    explained_variance   | -0.0176      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.00465     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 0.000367     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.89        |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 31           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0041050073 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.917       |
# |    explained_variance   | -0.0783      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0137      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.000368     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.89       |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 32          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008105971 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.872      |
# |    explained_variance   | -0.0392     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.008      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 0.000255    |
# -----------------------------------------
# Market Return : 423.10%   |   Portfolio Return : -78.93%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 33           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0034569954 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | -0.0287      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0191      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000945    |
# |    value_loss           | 0.000222     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 34           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0064356094 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0006       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 0.000229     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.23       |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 35          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006194544 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | -0.00521    |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0196      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 0.000201    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.23       |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 36          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006352692 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.000458    |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00616     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 0.000324    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 37           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0058183228 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.85        |
# |    explained_variance   | -0.0555      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0317      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 9.07e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 38           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0063574268 |
# |    clip_fraction        | 0.062        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.0101       |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.000904     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00346     |
# |    value_loss           | 0.000333     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.23       |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 39          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002991994 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.00317     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00875     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000292   |
# |    value_loss           | 0.000437    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.23       |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 40          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004575439 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | -0.0246     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0112     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 0.000253    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.23       |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 41          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005550881 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.00128     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.000671    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 42           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0064438665 |
# |    clip_fraction        | 0.0866       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.725       |
# |    explained_variance   | -8.94e-06    |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0168       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00494     |
# |    value_loss           | 0.000557     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 43           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0059452783 |
# |    clip_fraction        | 0.0788       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.665       |
# |    explained_variance   | 0.0168       |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0109       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00563     |
# |    value_loss           | 0.000105     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.23       |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 44          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002146456 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.0194      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0084     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000112   |
# |    value_loss           | 0.000149    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 45           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0032100936 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.517       |
# |    explained_variance   | 0.0116       |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0497       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000645    |
# |    value_loss           | 0.000651     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 46           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0025692973 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.443       |
# |    explained_variance   | -0.012       |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.00318     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000604    |
# |    value_loss           | 0.000409     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -2.23        |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 47           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0023657389 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.00024      |
# |    learning_rate        | 0.001        |
# |    loss                 | 6.17e-05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 0.000502     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -2.23       |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 48          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.002976766 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | -0.0145     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00701    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 0.000223    |
# -----------------------------------------
# Market Return : 423.10%   |   Portfolio Return : -18.44%   |
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 49           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0036893995 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.388       |
# |    explained_variance   | -0.00559     |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0132       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.000214     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 50           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0017709413 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.323       |
# |    explained_variance   | 0.000209     |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.00433     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000137     |
# |    value_loss           | 0.000294     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 597          |
# |    iterations           | 51           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0039382344 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | 0.00136      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.00661      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 0.000249     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 52           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0013115134 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | 0.00107      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0112       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000968    |
# |    value_loss           | 0.000274     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 53           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0036359648 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# |    explained_variance   | -0.0227      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.00722     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 0.000134     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 54           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0019945865 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.184       |
# |    explained_variance   | 0.00502      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.00145     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.000292     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | -1.55        |
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 55           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0024148258 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.167       |
# |    explained_variance   | 0.00708      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.000789    |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 0.000479     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -1.55       |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 56          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.001273986 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.135      |
# |    explained_variance   | 0.00271     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0039     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 0.000292    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | -1.55       |
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 57          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.001216202 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# ...
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.31e+04   |
# |    ep_rew_mean          | 0.0929     |
# | time/                   |            |
# |    fps                  | 594        |
# |    iterations           | 472        |
# |    time_elapsed         | 1627       |
# |    total_timesteps      | 966656     |
# | train/                  |            |
# |    approx_kl            | 0.01433735 |
# |    clip_fraction        | 0.0885     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.401     |
# |    explained_variance   | 0.000478   |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.000123   |
# |    n_updates            | 4710       |
# |    policy_gradient_loss | -0.00582   |
# |    value_loss           | 0.000297   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | 0.0929       |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 473          |
# |    time_elapsed         | 1630         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0106566055 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0.00673      |
# |    learning_rate        | 0.001        |
# |    loss                 | -0.0171      |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 0.0002       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 474         |
# |    time_elapsed         | 1633        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.009682072 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | -0.0102     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0193      |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 0.000269    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 475         |
# |    time_elapsed         | 1637        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.010995906 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | -0.00169    |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.031       |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 0.00045     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 476         |
# |    time_elapsed         | 1640        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.010622749 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.408      |
# |    explained_variance   | -0.0655     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00855    |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 0.000134    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 477         |
# |    time_elapsed         | 1643        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.007056685 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | -0.00589    |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00182     |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 0.000137    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 478         |
# |    time_elapsed         | 1646        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.008911374 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.489      |
# |    explained_variance   | -0.015      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0113     |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 0.00061     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 479         |
# |    time_elapsed         | 1650        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.008129735 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | -0.0199     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00569    |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 0.000156    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 480         |
# |    time_elapsed         | 1653        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.007118083 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.491      |
# |    explained_variance   | -0.000804   |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00385    |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 8.54e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.31e+04   |
# |    ep_rew_mean          | 0.0929     |
# | time/                   |            |
# |    fps                  | 594        |
# |    iterations           | 481        |
# |    time_elapsed         | 1656       |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.00774558 |
# |    clip_fraction        | 0.0917     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.518     |
# |    explained_variance   | -0.000369  |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.00337    |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.00065   |
# |    value_loss           | 0.000298   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 482         |
# |    time_elapsed         | 1659        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.011149881 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | -0.00705    |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0091     |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 0.000395    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.0929      |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 483         |
# |    time_elapsed         | 1662        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.007496462 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.0221      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00367     |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 0.000537    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | 0.0929       |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 484          |
# |    time_elapsed         | 1666         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0062118713 |
# |    clip_fraction        | 0.0786       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | -0.00853     |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.00793      |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.000951    |
# |    value_loss           | 0.000272     |
# ------------------------------------------
# Market Return : 423.10%   |   Portfolio Return : 174.83%   |
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 485         |
# |    time_elapsed         | 1669        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.008617836 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.384      |
# |    explained_variance   | 0.00198     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0241     |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 0.000239    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 486         |
# |    time_elapsed         | 1672        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.007135905 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.388      |
# |    explained_variance   | 0.0069      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00339     |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.000641   |
# |    value_loss           | 0.000234    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.31e+04     |
# |    ep_rew_mean          | 0.124        |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 487          |
# |    time_elapsed         | 1675         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0070203897 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.421       |
# |    explained_variance   | 0.0122       |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0313       |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | 0.00104      |
# |    value_loss           | 0.00023      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 488         |
# |    time_elapsed         | 1678        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.010896463 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | 0.00935     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00531     |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 0.000175    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.31e+04    |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 489         |
# |    time_elapsed         | 1681        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.011033138 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.393      |
# |    explained_variance   | -0.0181     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0241      |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 0.000193    |
# -----------------------------------------

# %%
model.save("my_trading_agent")

# %%
# Create the environment directly
env2 = TradingEnv(
    name="BTCUSD",
    df=df,  # Your dataset with your custom features
    positions=[-0.8, 0, 0.8],  # -1 (=SHORT), 0(=OUT), +1 (=LONG)
    trading_fees=0.01/100,  # 0.01% per stock buy/sell (Binance fees)
    borrow_interest_rate=0.0003/100,  # 0.0003% per timestep (one timestep = 1h here)
)

# %%
# Run an episode until it ends :
done, truncated = False, False
obs, info = env2.reset()
while not done and not truncated:
    action, _ = model.predict(obs)
    obs, reward, done, truncated, info = env2.step(action)
    # ... (evaluate further)
# Out:
# Market Return : 423.10%   |   Portfolio Return : 240.58%   |

# %%
# At the end of the episode you want to render
env2.unwrapped.save_for_render(dir="render_logs")
